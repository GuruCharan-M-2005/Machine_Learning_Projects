# %% [markdown]
# # House Price Prediction
#
# *House price prediction can help the developer determine the selling price of a house and can help the customer to arrange the right time to purchase a house. There are three factors that influence the price of a house which include physical conditions, concept and location.*
#
# ![house price.png](attachment:6c80cb0f-b477-4cce-a0e1-c860f0c1970e.png)
#
# # Importing Libraries and Data

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import plotly.express as px

import warnings
warnings.filterwarnings(category=UserWarning,action='ignore')

# %%
data=pd.read_csv('Housing.csv')
df=pd.DataFrame(data)
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# # Data Pre-Processing and Training

# %%
df=df.drop(['stories','mainroad','guestroom','basement','parking','hotwaterheating','airconditioning'
           ,'parking','furnishingstatus','prefarea'],axis='columns')
df.head()
# Out:
#       price  area  bedrooms  bathrooms
# 0  13300000  7420         4          2
# 1  12250000  8960         4          4
# 2  12250000  9960         3          2
# 3  12215000  7500         4          2
# 4  11410000  7420         4          1

# %%
x=df.drop(['price'],axis='columns')
x.head()
# Out:
#    area  bedrooms  bathrooms
# 0  7420         4          2
# 1  8960         4          4
# 2  9960         3          2
# 3  7500         4          2
# 4  7420         4          1

# %%
y=df.price
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8)
xtrain.head()
# Out:
#      area  bedrooms  bathrooms
# 355  8250         3          1
# 439  3930         2          1
# 199  4200         3          1
# 109  6615         4          2
# 369  3600         2          1

# %%
lm=LinearRegression()
lm.fit(xtrain,ytrain)
lm
# Out:
# LinearRegression()

# %%
lm.score(xtest,ytest)
# Out:
# 0.4256376728455633

# %%
lm.predict([[2500,3,1]])
# Out:
# array([3302965.59312494])

# %% [markdown]
# # Visualisation

# %%
px.scatter(df,x='area',y='price',title='Area vs Price')

# %%
fig=px.histogram(df,x='price',title='Area vs Price')
fig.update_layout(bargap=0.2)

# %% [markdown]
# # Great Job...!!!
